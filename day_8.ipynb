# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-com-commits/python_codes/blob/main/day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input('enter value: ')
# Out:
# enter value: 5
# '5'

# %%
result = input('enter a value: ')
# Out:
# enter a value: 7

# %%
result
# Out:
# '7'

# %%
type(result)
# Out:
# str

# %%
result_int = int(result)

# %%
type(result_int)
# Out:
# int

# %%
row1 = [' ',' ',' ']
row2 = [' ',' ',' ']
row3 = [' ',' ',' ']
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
position_index = input('enter the position: ')
# Out:
# enter the position: 1

# %%
type(position_index)
# Out:
# str

# %%
row1[position_index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4293293610.py in <cell line: 0>()
# ----> 1 row1[position_index]
#
# TypeError: list indices must be integers or slices, not str

# %%
position_index = int(input('enter the position: '))
# Out:
# enter the position: 1

# %%
row1[position_index]
# Out:
# ' '

# %%
type(position_index)
# Out:
# int

# %%
result = int(input('guess a number: '))
# Out:
# guess a number: nine
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4290629491.py in <cell line: 0>()
# ----> 1 result = int(input('guess a number: '))
#
# ValueError: invalid literal for int() with base 10: 'nine'

# %%
some_value = '100'

# %%
some_value.isdigit()
# Out:
# True

# %%
def game_list = [0,1,2]
# Out:
#   File "/tmp/ipython-input-800989885.py", line 1
#     def game_list = [0,1,2]
#                   ^
# SyntaxError: expected '('

# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
  print('here is the current list: ')
  print(game_list)

# %%
display_game(game_list)
# Out:
# here is the current list:
# [0, 1, 2]

# %%
def position_choice():
  choice = 'wrong'
  while choice not in ['0','1','2']:
    choice = input('pick a position (0,1,2): ')

    if choice not in ['0','1','2']:
      print('sorry, invalid choice')
  return int(choice)

# %%
position_choice()
# Out:
# pick a position (0,1,2): 1
# 1

# %%
def replacement_choice(game_list,position):
  user_replacement = input('type a string to place at position')

  game_list[position] = user_replacement
  return(game_list)

# %%
replacement_choice(game_list,1)
# Out:
# type a string to place at positionflex
# [0, 'flex', 2]

# %%
def gameon_choice():
  choice = 'wrong'
  while choice not in ['y' , 'n']:
    choice = input('keep playing ? (y or n)')

    if choice not in ['y' , 'n']:
      print('sorry, i do not understand, please choose y or n')

  if choice == 'y':
      return(True)
  else:
      return(False)

# %%
gameon_choice()
# Out:
# keep playing ? (y or n)n
# False

# %%
game_on = True
game_list = [0,1,2]

while game_on:
    display_game(game_list)
    position = position_choice()
    game_list = replacement_choice(game_list,position)
    display_game(game_list)
    game_on = gameon_choice()
# Out:
# here is the current list:
# [0, 1, 2]
# pick a position (0,1,2): 2
# type a string to place at positionn
# here is the current list:
# [0, 1, 'n']
# keep playing ? (y or n)n

# %%
def display_board(board):
    print(board[7]+'|' +board[8]+ '|' +board[9])
    print('-|-|-')
    print(board[4]+'|' +board[5]+ '|' +board[6])
    print('-|-|-')
    print(board[1]+'|' +board[2]+ '|' +board[3])

# %%
test_board = [' ']*10
display_board(test_board)
# Out:
#  | |
# -|-|-
#  | |
# -|-|-
#  | |

# %%
def player_input():
    choice = ''
    while choice not in ['x', 'o']:
        choice = input('player1 choose (x or o): ')

    player1 = choice
    player2 = 'o'
    if player1 == 'x':
      player2 = 'o'
    else:
      player2 = 'x'

    return(player1, player2)

# %%
player_input()
# Out:
# player1 choose (x or o): x
# ('x', 'o')

# %%
def place_marker(board, marker, position):
    board[position] = marker

# %%
test_board = ['#','x','o','x','o','x','o','x','o','x']

# %%
place_marker(test_board,'$', 8)
display_board(test_board)
# Out:
# x|$|x
# -|-|-
# o|x|o
# -|-|-
# x|o|x

# %%
def win_check(board,mark):
    #win tic tac toe?

    #all rows check to see if they all share the same marker ?
    return ((board[7]== mark and board[8]== mark and board[9] == mark) or
    (board[4]== mark and board[5]== mark and board[6]== mark) or
    (board[1]== mark and board[2]== mark and board[3]== mark) or
    (board[7]== mark and board[5]== mark and board[3]== mark) or
    (board[1]== mark and board[5]== mark and board[9]== mark) or
    (board[7]== mark and board[4]== mark and board[1]== mark) or
    (board[8]== mark and board[5]== mark and board[2]== mark) or
    (board[9]== mark and board[6]== mark and board[3]== mark))
    #all columns , check to see  if marker matches
    #diagonal check to see match

# %%
import random
def choose_first():
    flip = random.randint(0,1)

    if flip == 0:
        return('player 1')
    else:
        return('player 2')

# %%
def space_check(board,position):
  return(board[position]== '')

# %%
def full_board_check(board):
  for i in range(1,10):
    if space_check(board,i):
      return(False)
      #board is full is we return True
    return(True)

# %%
def player_choice(board):
    position = 'ghh'
    while position not in [1,2,3,4,5,6,7,8,9] or not space_check(board,position):
        position = int(input('choose a position (1-9)'))
    return(position)

# %%
def replay():
    choice == input('play again ? yes or no')
    return(choice == 'yes')

# %%
print('Welcome to TIC TAC TOE')

while True:
    the_board = [' '] * 10
    player1_marker, player2_marker = player_input()
    turn = choose_first()
    print(turn + ' will go first')

    play_game = input('Ready to play? y or n: ')
    game_on = play_game == 'y'

    while game_on:
        display_board(the_board)

        if turn == 'Player 1':
            position = player_choice(the_board)
            place_marker(the_board, player1_marker, position)

            if win_check(the_board, player1_marker):
                display_board(the_board)
                print('Player 1 has won!')
                game_on = False
            elif full_board_check(the_board):
                display_board(the_board)
                print('Tie game!')
                break
            else:
                turn = 'Player 2'

        else:
            position = player_choice(the_board)
            place_marker(the_board, player2_marker, position)

            if win_check(the_board, player2_marker):
                display_board(the_board)
                print('Player 2 has won!')
                game_on = False
            elif full_board_check(the_board):
                display_board(the_board)
                print('Tie game!')
                break
            else:
                turn = 'Player 1'

    if not replay():
        break
# Out:
# Welcome to TIC TAC TOE
# player 1 will go first
#  | |
# -|-|-
#  | |
# -|-|-
#  | |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4113607127.py in <cell line: 0>()
#      29
#      30         else:
# ---> 31             position = player_choice(the_board)
#      32             place_marker(the_board, player2_marker, position)
#      33
#
# /tmp/ipython-input-2156070949.py in player_choice(board)
#       2     position = 'ghh'
#       3     while position not in [1,2,3,4,5,6,7,8,9] or not space_check(board,position):
# ----> 4         position = int(input('choose a position (1-9)'))
#       5     return(position)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# ...
