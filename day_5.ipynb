# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-com-commits/python_codes/blob/main/day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 == 2 #shift + enter
# Out:
# True

# %%
'2' == 2
# Out:
# False

# %%
2 == 3
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
'hello' == 'bye'
# Out:
# False

# %%
'Bye' == 'bye'
# Out:
# False

# %%
3 != 3
# Out:
# False

# %%
4 != 2
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
2<1
# Out:
# False

# %%
1<2<3
# Out:
# True

# %%
1<2>3
# Out:
# False

# %%
1<2 and 2<3
# Out:
# True

# %%
'h' == 'h' and 2 == 2
# Out:
# True

# %%
('h' == 'h') and (2 == 2)
# Out:
# True

# %%
1 == 1 or 2==2
# Out:
# True

# %%
100 == 1 or 2 == 2
# Out:
# True

# %%
100 == 1 or 2==200
# Out:
# False

# %%
100 == 1 or 2==2
# Out:
# True

# %%
100==1 and 2==2
# Out:
# False

# %%
400 > 5000
# Out:
# False

# %%
not (400 > 5000)
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
not (1==1)
# Out:
# False
