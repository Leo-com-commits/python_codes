# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-com-commits/python_codes/blob/main/day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mylist = [1,2,3] #shift+enter
mylist.append(4)

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist.pop()
# Out:
# 4

# %%
mylist
# Out:
# [1, 2, 3]

# %%
help(mylist.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
def add_function(num1,num2):
  return (num1+num2)

# %%
result = add_function(5,2)
print(result)
# Out:
# 7

# %%
def sub_function(num1,num2):
  return(num1-num2)

# %%
result = sub_function(7,5)
print(result)
# Out:
# 2

# %%
def mul_function(num1,num2):
  return(num1*num2)

# %%
result = mul_function(5,2)
print(result)

# %%
def say_hello():
  print('hello')

# %%
say_hello()
# Out:
# hello

# %%
def say_hello():
  print('hello')
  print('how')
  print('are')
  print('you')
  print('?')

# %%
say_hello()
# Out:
# hello
# how
# are
# you
# ?

# %%
def say_hello(name='Souvik'):
  print(f'hello {name}')

# %%
say_hello()
# Out:
# hello Souvik

# %%
def print_result(a,b):
  print(a+b)

# %%
result = print_result(5,5)
result
# Out:
# 10

# %%
result

# %%
type(result)
# Out:
# NoneType

# %%
def return_result(a,b):
  return(a+b)

# %%
result = return_result(5,5)
result
# Out:
# 10

# %%
type(result)
# Out:
# int

# %%
def sum_numbers(num1,num2):
  return(num1+num2)

# %%
sum_numbers(10,20)
# Out:
# 30

# %%
sum_numbers('10','20')
# Out:
# '1020'

# %%
2%2
# Out:
# 0

# %%
3 %2
# Out:
# 1

# %%
20 % 2 == 0
# Out:
# True

# %%
21 % 2 == 0
# Out:
# False

# %%
def even_check(number):
  result = number%2 == 0
  return(result)

# %%
even_check(10)
# Out:
# True

# %%
even_check(5)
# Out:
# False

# %%
def even_check(number):
  return(number%2 ==0)

# %%
even_check(10)
# Out:
# True

# %%
def even_check_number(num_list):
  for number in num_list:
    if number%2 == 0:
      return(True)
    else:
      pass

# %%
even_check_number([2,4,7])
# Out:
# True

# %%
even_check_number([7,9,3])

# %%
even_check_number([2,1,1])
# Out:
# True

# %%
even_check_number([1,1,2])
# Out:
# True

# %%
#return true if there is any even number in the list.

# %%
def even_check_number(num_list):
  for number in num_list:
    if number%2 == 0:
      return(True)
    else:
      pass
      return(False)

# %%
even_check_number([3,4,5])
# Out:
# False

# %%
def check_even_list(num_list):
    even_numbers = []
    for number in num_list:
        if number%2 == 0:
            even_numbers.append(number)
        else:
            pass
    return (even_numbers)

# %%
check_even_list([1,2,3,4,5])
# Out:
# [2, 4]

# %%
stock_prices = [('APPL',200),('DELL',400),('NOKIA',500)]
for item in stock_prices:
  print(item)
# Out:
# ('APPL', 200)
# ('DELL', 400)
# ('NOKIA', 500)

# %%
for product,prices in stock_prices:
  print(prices)
# Out:
# 200
# 400
# 500

# %%
for product,prices in stock_prices:
  print(prices+(0.1)*prices)
# Out:
# 220.0
# 440.0
# 550.0

# %%
work_hours = [('Souvik',100),('leo',400),('zainab',800)]

# %%
def employee_check(work_hours):
    current_max = 0
    employee_of_month = ''
    for employee,hours in work_hours:
        if  hours>current_max:
            current_max = hours
            employee_of_month = employee
        else:
            pass
    return(employee_of_month,current_max)

# %%
employee_check(work_hours)
# Out:
# ('zainab', 800)

# %%
result = employee_check(work_hours)

# %%
result
# Out:
# ('zainab', 800)

# %%
Name , Hours = employee_check(work_hours)

# %%
Name
# Out:
# 'zainab'

# %%
Hours
# Out:
# 800

# %%
example = [1,2,3,4,5,6,7,8,9]
from random import shuffle
shuffle(example)

# %%
result = shuffle(example)

# %%
result

# %%
def shuffle_list(example):
  shuffle(example)
  return(example)

# %%
result = shuffle_list(example)

# %%
result
# Out:
# [4, 9, 5, 7, 6, 8, 1, 2, 3]

# %%
example2 = [1,2,3,4,5,6,7]
def shuffle_list(example2):
  shuffle(example2)
  return(example2)

# %%
result = shuffle_list(example2)

# %%
result
# Out:
# [2, 1, 5, 7, 3, 6, 4]

# %%
def player_guess():
  guess = ''
  while guess not in ['0','1','2']:
    guess = input('pick up any number: 0,1,2')
  return int(guess)

# %%
player_guess()
# Out:
# pick up any number: 0,1,22
# 2

# %%
myindex = player_guess()
# Out:
# pick up any number: 0,1,21

# %%
myindex
# Out:
# 1

# %%
def myfunc(a,b):
  return(sum((a,b))*0.05)

# %%
result = myfunc(60,40)

# %%
print(result)
# Out:
# 5.0

# %%
def myfunc(a,b,c=0,d=0):
  return(sum((a,b,c,d))*0.05)

# %%
result = myfunc(25,70)

# %%
print(result)
# Out:
# 4.75

# %%
def myfunc(*args):
  return(sum((args))*0.05)

# %%
result = myfunc(10+90)

# %%
print(result)
# Out:
# 5.0

# %%
def myfunc(*args):
  print(args)

# %%
myfunc(10,20,40)
# Out:
# (10, 20, 40)

# %%
def myfunc(*spam):
  return(sum((spam))*5)

# %%
myfunc(10,20,70)
# Out:
# 500

# %%
def myfunct(*args):
  for item in args:
    print(item)

# %%
myfunct(10,2,345,67,89)
# Out:
# 10
# 2
# 345
# 67
# 89

# %%
def myfunc(**kwargs):
  if 'fruit' in kwargs:
    print('i like {}'.format(kwargs['fruit']))
  else:
    print('i did not like fruit')

# %%
myfunc(fruit= ' apple')
# Out:
# i like  apple

# %%
def myfunc(*args,**kwargs):
  print('I like {} {}'.format(args[0],kwargs['food']))

# %%
myfunc(10,food = 'eggs')
# Out:
# I like 10 eggs

# %%
def myfunc(*args,**kwargs):
  print(args)
  print(kwargs)
  print('I like {} {}'.format(args[0],kwargs['food']))

# %%
myfunc(10,20,30,veggie = 'lettuice',food = 'eggs')
# Out:
# (10, 20, 30)
# {'veggie': 'lettuice', 'food': 'eggs'}
# I like 10 eggs

# %%
mylist = ['a','b','c']
''.join(mylist)
# Out:
# 'abc'

# %%
def square(num):
  return(num**2)

# %%
my_num = [1,2,3,4]

# %%
for item in map(square,my_num):
  print(item)
# Out:
# 1
# 4
# 9
# 16

# %%
list(map(square,my_num))
# Out:
# [1, 4, 9, 16]

# %%
def even(num):
  return(num%2==0)

# %%
nums = [1,2,3,4,5,6,7,8]

# %%
list(filter(even,nums))
# Out:
# [2, 4, 6, 8]

# %%
for item in filter(even,nums):
  print(item)
# Out:
# 2
# 4
# 6
# 8

# %%
myfunc = lambda num:num**2

# %%
myfunc(6)
# Out:
# 36

# %%
list(map(lambda num:num **2,nums))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
list(filter(lambda num:num%2 == 0,nums))
# Out:
# [2, 4, 6, 8]

# %%
x = 25
def myfunc():
  x = 50
  return(x)

# %%
print(x)
# Out:
# 25

# %%
name = 'the global star'
def greet():
  name = 'Souvik'
  def hello():
    print('hello'+ name)

# %%
greet()

# %%
def palindrome(s):
  s = s.replace(' ','')
  return( s == s[::-1])

# %%
palindrome('madam')
# Out:
# True

# %%
print([1,2,3])
print([4,5,6])
print([7,8,9])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
def mylist(row1,row2,row3):
  print(row1)
  print(row2)
  print(row3)

# %%
s = [1,2,3]
mylist(s,s,s)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
row1 = ['','','']
row2 = ['','','']
row3 = ['','','']

# %%
mylist(row1,row2,row3)
# Out:
# ['', '', '']
# ['', '', '']
# ['', '', '']

# %%
row2[1]= 'S'
mylist(row1,row2,row3)
# Out:
# ['', '', '']
# ['', 'S', '']
# ['', '', '']
