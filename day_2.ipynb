# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-com-commits/python_codes/blob/main/day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'Souvik' #shift +enter
#name[0]= 'm'

# %%
last_letter=name[1:]

# %%
last_letter
# Out:
# 'ouvik'

# %%
'm'+last_letter
# Out:
# 'mouvik'

# %%
x = 'hello world '
x+ 'it is beautiful outside'
# Out:
# 'hello world it is beautiful outside'

# %%
x = 'hello world '
x= x+ 'it is beautiful outside'
x
# Out:
# 'hello world it is beautiful outside'

# %%
letter = 'z'
letter*10
# Out:
# 'zzzzzzzzzz'

# %%
2+3
# Out:
# 5

# %%
'2' + '5'
# Out:
# '25'

# %%
x = 'hello world'
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['hello', 'world']

# %%
x = 'hi this is a string'
x.split()
# Out:
# ['hi', 'this', 'is', 'a', 'string']

# %%
x = 'this is who i am'
x.split('i')
# Out:
# ['th', 's ', 's who ', ' am']

# %%
print('there is a dog{}'.format(' and cat'))
# Out:
# there is a dog and cat

# %%
print('this is a string{} '.format(' INSERTED'))
# Out:
# this is a string INSERTED

# %%
print('the {},{},{}'.format('fox','brown','red'))
# Out:
# the fox,brown,red

# %%
print('the {2},{0},{1}'.format('fox','brown','quick'))
# Out:
# the quick,fox,brown

# %%
print('the {0},{0},{0}'.format('fox','brown','quick'))
# Out:
# the fox,fox,fox

# %%
print('the {b} {f} {q}'.format(f='fox',b='brown',q='quick'))
# Out:
# the brown fox quick

# %%
r=result = 100/3
r
# Out:
# 33.333333333333336

# %%
print("the result was {r:1.3f}".format( r= result))
# Out:
# the result was 33.333

# %%
print("the result was {r:1.5f}".format( r= result))
# Out:
# the result was 33.33333

# %%
r = result=100/777
r
# Out:
# 0.1287001287001287

# %%
print("the result was {r:1.2f}".format(r=result))
# Out:
# the result was 0.13

# %%
name= 'Souvik'
print('my name is {}'.format(name))
# Out:
# my name is Souvik

# %%
name= 'Souvik'
print(f'my name is {name}')
# Out:
# my name is Souvik

# %%
name = 'Souvik'
age = 22
print(f"{name} is {age} years old")
# Out:
# Souvik is 22 years old

# %%
print('the {},{},{}'.format('fox','brown','red'))
# Out:
# the fox,brown,red

# %%
print('the {1},{0},{2}'.format('fox','brown','red'))
# Out:
# the brown,fox,red

# %%
print('the {q} {b} {f}'.format(q='dog',b='is', f='barking'))
# Out:
# the dog is barking
