# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-com-commits/python_codes/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_string = (1,2,3) #shift+enter
my_string = ('string',123, 678.2)
len(my_string)
# Out:
# 3

# %%
mystring = ["one", "two", "three"]
mystring[0]
# Out:
# 'one'

# %%
mystring[1:]
# Out:
# ['two', 'three']

# %%
mylist = ['one','two','three']
mylist
# Out:
# ['one', 'two', 'three']

# %%
anotherlist = ['four','five']
mylist + anotherlist
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
mylist = ['one','two','three']
anotherlist = ['four','five']
mylist + anotherlist
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list = mylist + anotherlist
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0] = 'One All Caps'
new_list
# Out:
# ['One All Caps', 'two', 'three', 'four', 'five']

# %%
new_list = ['One All Caps', 'two', 'three', 'four', 'five']
new_list
# Out:
# ['One All Caps', 'two', 'three', 'four', 'five']

# %%
new_list.append('six')
new_list
# Out:
# ['One All Caps', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.append('seven')

# %%
new_list
# Out:
# ['One All Caps', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
new_list.pop()
# Out:
# 'seven'

# %%
new_list
# Out:
# ['One All Caps', 'two', 'three', 'four', 'five', 'six']

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'six'

# %%
new_list
# Out:
# ['One All Caps', 'two', 'three', 'four', 'five']

# %%
new_list.pop(0)
# Out:
# 'One All Caps'

# %%
new_list
# Out:
# ['two', 'three', 'four', 'five']

# %%
new_list = ['two', 'three','four','five']
new_list
# Out:
# ['two', 'three', 'four', 'five']

# %%
new_list.pop(-1)
# Out:
# 'five'

# %%
new_list
# Out:
# ['two', 'three', 'four']

# %%
new_list = ['two', 'three', 'four', 'five']
new_list
# Out:
# ['two', 'three', 'four', 'five']

# %%
new_list = ['a','e', 'x', 'b','c']
num_list = [4,1,8,3]
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
my_new_list = new_list
my_new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]

# %%
my_dict = {'key 1':'value 1','key 2':'value 2'}
my_dict
# Out:
# {'key 1': 'value 1', 'key 2': 'value 2'}

# %%
my_dict['key 1']
# Out:
# 'value 1'

# %%
my_dict['key 2']
# Out:
# 'value 2'

# %%
prices_lookup = {'guava':10,'orange':5,'mango':11,'banana':6}
prices_lookup['mango']
# Out:
# 11

# %%
d = {'k1':123,'k2':[0,1,2],'k3':{'direct':1444}}
d['k1']
# Out:
# 123

# %%
d['k3']
# Out:
# {'direct': 1444}

# %%
d['k2']
# Out:
# [0, 1, 2]

# %%
d['k3']['direct']
# Out:
# 1444

# %%
d['k2'][2]
# Out:
# 2

# %%
d = {'key1':['a','b','c']}
d
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
d['key1']
# Out:
# ['a', 'b', 'c']

# %%
mylist = d
mylist
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
mylist = d['key1']
mylist
# Out:
# ['a', 'b', 'c']

# %%
letter = mylist[2]
letter
# Out:
# 'c'

# %%
letter.upper()
# Out:
# 'C'

# %%
letter = mylist[1]
letter
# Out:
# 'b'

# %%
letter.upper()
# Out:
# 'B'

# %%
d['key1'][2].upper()
# Out:
# 'C'

# %%
d = {'key1':100,'key2':200}
d
# Out:
# {'key1': 100, 'key2': 200}

# %%
d['key3'] = 300
d
# Out:
# {'key1': 100, 'key2': 200, 'key3': 300}

# %%
d['key1'] = 'KEY VALUE'
d
# Out:
# {'key1': 'KEY VALUE', 'key2': 200, 'key3': 300}

# %%
d = {'key1': 100, 'key2': 200, 'key3': 300}
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300])

# %%
d.items()
# Out:
# dict_items([('key1', 100), ('key2', 200), ('key3', 300)])

# %%
new_list = ['a','z','y','c','b']
new_list
# Out:
# ['a', 'z', 'y', 'c', 'b']

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'y', 'z']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['z', 'y', 'c', 'b', 'a']

# %%
d = {'january':1,'february':2}
d
# Out:
# {'january': 1, 'february': 2}

# %%
d.values()
# Out:
# dict_values([1, 2])

# %%
d['march'] = 3
d
# Out:
# {'january': 1, 'february': 2, 'march': 3}

# %%
d['april']=4
d
# Out:
# {'january': 1, 'february': 2, 'march': 3, 'aplril': 4, 'april': 4}

# %%
d.values()
# Out:
# dict_values([1, 2, 3, 3])

# %%
d['january'] = 'JANUARY'
d
# Out:
# {'january': 'JANUARY', 'february': 2, 'march': 3, 'aplril': 4, 'april': 4}

# %%
new_list = ['a','c','d','b']
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['d', 'c', 'b', 'a']

# %%
new_list = ['one','two','three']
new_list.append('six')

# %%
new_list
# Out:
# ['one', 'two', 'three', 'six']

# %%
new_list.pop()
# Out:
# 'six'

# %%
new_list
# Out:
# ['one', 'two', 'three']

# %%
my_new_list = ['a','b','c']
my_new_list.append('d')

# %%
my_new_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_new_list.pop()
# Out:
# 'd'

# %%
my_new_list
# Out:
# ['a', 'b', 'c']

# %%
d = {'key 1':1,'key 2':2,'key 3':3}
d
# Out:
# {'key 1': 1, 'key 2': 2, 'key 3': 3}

# %%
d['key 1']
# Out:
# 1

# %%
d['key 2']
# Out:
# 2

# %%
d['key 3'] = 100

# %%
d
# Out:
# {'key 1': 1, 'key 2': 2, 'key 3': 100}
